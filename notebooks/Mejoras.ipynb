# %% [markdown]
# ### 1. **Preprocesamiento de Datos**
#    - **Eliminar outliers**: Revisa cada *feature* en relación al precio para identificar y eliminar los puntos que desentonan. Haz esto antes de dividir el dataset en *train* y *test*.
#    - **Probar IsolationForest**: Implementa el algoritmo *IsolationForest* para detectar y eliminar anomalías en los datos.
#    - **Eliminar features redundantes**: Revisa si hay *features* duplicadas o irrelevantes, como el caso de "bedroom2" que es duplicada de "rooms". Elimina estos duplicados tanto en el *train* como en el *test set*.
#    - **Crear nuevas features**: Considera generar nuevas *features*, como la edad del edificio, el precio medio en la zona, etc., para enriquecer el dataset.
#
# ### 2. **Selección de Features**
#    - **Probar k_selector**: Experimenta con técnicas de selección de características para reducir la dimensionalidad.
#    - **Usar mutual_info_regression**: Prueba esta técnica para evaluar la importancia de las *features*. Detecta relaciones más complejas que solo la correlación lineal.
#
# ### 3. **Modelado**
#    - **Probar diferentes modelos**:
#      - RandomForest
#      - SVR (Support Vector Regressor)
#      - KNeighbors
#      - Linear Regression
#      - Modelos de *sklearn.ensemble* (p.ej. GradientBoostingRegressor, StackingRegressor)
#
# ### 4. **Optimización de Hiperparámetros**
#    - **Optuna**: Usa la librería *Optuna* para la optimización de hiperparámetros. Esto puede ser más eficiente que el *GridSearch* tradicional.
#
# ### 5. **Escalado y Normalización de los Datos**
#    - **Probar diferentes Imputers**: Experimenta con diversas técnicas de imputación para manejar datos faltantes.
#    - **Probar diferentes Scalers**:
#      - Usa *RobustScaler*, especialmente si tienes outliers, ya que puede funcionar mejor que el *StandardScaler* en estos casos.
#
# ### 6. **Uso de Pipelines**
#    - Implementa *Pipelines* para automatizar el proceso de preprocesamiento, selección de características, y modelado.
